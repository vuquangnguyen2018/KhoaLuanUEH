# %%
import pandas as pd
#import os
#pip install openpyxl
import numpy as np
#import scipy as sp

# %%
Data=pd.read_excel("DataCS-2018-2021.xlsx",
                   sheet_name=None,
                   usecols="B:P",
                   skipfooter=15,
                   header=7)



#LOADING SHEETS
Data18=Data['2018']
Data19=Data['2019']
Data20=Data['2020']
Data21=Data['2021']

#Data.keys()
#RENAME

# RENAME COLUMNS
new_columns = {0: 'Ma CK', 
               1: 'Ten Cong ty',
               2: 'San',
               3: 'Nhom nganh',
               4: 'Tong Tai san',
               5: 'Tong No phai tra',
               6: 'Von Chu so huu',
               7: 'No ngan han',
               8: 'No dai han',
               9: 'Tai san co dinh',
               10: 'Gia von hang ban',
               11: 'Loi nhuan truoc thue',
               12: 'Chi phi lai vay',
               13: 'Von hoa thi truong',
               14: 'ROA'               
              }

#RENAME and DROP ROWS

Data18=Data18.rename(columns={Data18.columns[i]: new_col for i, new_col in new_columns.items()})
Data19=Data19.rename(columns={Data19.columns[i]: new_col for i, new_col in new_columns.items()})
Data20=Data20.rename(columns={Data20.columns[i]: new_col for i, new_col in new_columns.items()})
Data21=Data21.rename(columns={Data21.columns[i]: new_col for i, new_col in new_columns.items()})

#DROP ROW 1-2
Data18.drop([0,1], axis=0, inplace=True)
Data19.drop([0,1], axis=0, inplace=True)
Data20.drop([0,1], axis=0, inplace=True)
Data21.drop([0,1], axis=0, inplace=True)

# LOC trong San Giao dich HOSE HNX UPCOM
San_GD = ['HOSE','HNX','UPCOM']
Data18 = Data18[Data18['San'].isin(San_GD)].sort_values(by=['Von hoa thi truong'], ascending=False)
Data19 = Data19[Data19['San'].isin(San_GD)].sort_values(by=['Von hoa thi truong'], ascending=False)
Data20 = Data20[Data20['San'].isin(San_GD)].sort_values(by=['Von hoa thi truong'], ascending=False)
Data21 = Data21[Data21['San'].isin(San_GD)].sort_values(by=['Von hoa thi truong'], ascending=False)

# %%
# Tong hop Du lieu tu Nam 2018 - 2021
Data18['Nam']=2018
Data19['Nam']=2019
Data20['Nam']=2020
Data21['Nam']=2021
# Ket hop GDP va COVID
DataGDP_COVID=pd.read_csv("DataGDP_COVID.csv")
DataNganh=pd.read_csv("Index_NhomNganh.csv")

# Data Tong hop
DataAll=pd.concat([Data18, Data19,Data20,Data21]).reset_index(drop=True)
DataAll=DataAll.merge(DataGDP_COVID, how='left', on='Nam')
DataAll=DataAll.merge(DataNganh, how='left', on='Nhom nganh')
# Out:
#      Ma CK                          Ten Cong ty    San            Nhom nganh  \
# 444    VMD                Y Dược phẩm Vimedimex   HOSE  Dược phẩm và Y tế L1
# 1765   VMD                Y Dược phẩm Vimedimex   HOSE  Dược phẩm và Y tế L1
# 3086   VMD                Y Dược phẩm Vimedimex   HOSE  Dược phẩm và Y tế L1
# 2725   DVN           Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 4046   DVN           Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# ...    ...                                  ...    ...                   ...
# 3950   DMH                        Dược Minh Hải  UPCOM  Dược phẩm và Y tế L1
# 4259   NDC                   Dược phẩm Nam Dược  UPCOM  Dược phẩm và Y tế L1
# 4299   JVC  Đầu tư và Phát triển Y tế Việt Nhật   HOSE  Dược phẩm và Y tế L1
# 5259   CBV                      CTCBIO Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 5271   DMH                        Dược Minh Hải  UPCOM  Dược phẩm và Y tế L1
#
#        Tong Tai san Tong No phai tra Von Chu so huu    No ngan han  \
# 444   9747612126653    9406847754589   340764372064  9383720145639
# 1765  9004433259349    8664716002069   339717257280  8639617520294
# 3086  8305837889260    7942056554408   363781334852  7918440798737
# 2725  6103135625011    3194218954138  2908916670873  3136938847527
# 4046  5862093977660    2867374219901  2994719757759  2816370849290
# ...             ...              ...            ...            ...
# 3950            NaN              NaN            NaN            NaN
# 4259            NaN              NaN            NaN            NaN
# 4299            NaN              NaN            NaN            NaN
# 5259            NaN              NaN            NaN            NaN
# 5271            NaN              NaN            NaN            NaN
#
#        No dai han Tai san co dinh Gia von hang ban Loi nhuan truoc thue  \
# 444   23127608950    106625217747  -13779978811705          46227624877
# 1765  25098481775    132208629146  -16749881313947          49830004459
# 3086  23615755671    136690371938  -16638113672113          50489455711
# 2725  57280106611    321896945006   -4797711488517         238032164309
# 4046  51003370611    331084484398   -4433827644346         234445262596
# ...           ...             ...              ...                  ...
# 3950          NaN             NaN              NaN                  NaN
# 4259          NaN             NaN              NaN                  NaN
# 4299          NaN             NaN              NaN                  NaN
# 5259          NaN             NaN              NaN                  NaN
# 5271          NaN             NaN              NaN                  NaN
#
#      Chi phi lai vay Von hoa thi truong       ROA   Nam   GDP  COVID   INDS
# 444     -42381175237         401.446968  0.000917  2018  7.17      0      7
# 1765    -17342856181         401.446968  0.000917  2019  7.02      0      7
# 3086     -8371855404         401.446968  0.000917  2020  2.91      1      7
# 2725    -73992059074           4634.772   0.01985  2020  2.91      1      7
# 4046    -59454036669           4634.772   0.01985  2021  2.58      1      7
# ...              ...                ...       ...   ...   ...    ...    ...
# 3950             NaN                  0       NaN  2020  2.91      1      7
# 4259             NaN            814.086       NaN  2021  2.58      1      7
# 4299             NaN         649.125987 -0.044005  2021  2.58      1      7
# 5259             NaN                  0  0.161435  2021  2.58      1      7
# 5271             NaN                  0       NaN  2021  2.58      1      7
#
# [240 rows x 19 columns]

# %%
#Don Vi la Unit: Million M
DataAll.iloc[:,4:13]=DataAll.iloc[:,4:13]//10**6 # Chia lay lam tron
#Von hoa thi truong, Unit: Ty dong, Billion  
DataAll['Von hoa thi truong']=DataAll['Von hoa thi truong'].apply(np.ceil)  #lam trong so tu nhien

# %%
# Tinh toan Nang cao
#GRWTH = MarketCap / Book value of Equity
DataAll['GRWTH']=DataAll['Von hoa thi truong']/DataAll['Von Chu so huu']
# SIZE = natural logarithym LN(Total ASSETS)
DataAll['SIZE'] = np.log(DataAll['Tong Tai san'].astype('float'))
# EBIT = LNTT + Chi phi lai vay => PRO = EBIT/Total Assets ; RISK=Std(EBIT)
DataAll['EBIT']=DataAll['Loi nhuan truoc thue']+abs(DataAll['Chi phi lai vay'])
# Profitability PRO = EBIT/Tong Tai san
DataAll['PROF']=DataAll['EBIT']/DataAll['Tong Tai san']
# LIQD	Tổng tài sản ngắn hạn/ Nợ ngắn hạn
DataAll['LIQD']=DataAll['Tong Tai san']/DataAll['No ngan han']
# UNIQ	Giá vốn hàng bán/Tổng tài sản
DataAll['UNIQ']=abs(DataAll['Gia von hang ban'])/DataAll['Tong Tai san']
# Tính hữu hình	TANG	Tài sản cố định/ Tổng tài sản
DataAll['TANG']=DataAll['Tai san co dinh']/DataAll['Tong Tai san']
#BIEN PHU THUOC: STLEV, LTLEV, BLEV
DataAll['STLEV']=DataAll['No ngan han']/DataAll['Tong Tai san']
DataAll['LTLEV']=DataAll['No dai han']/DataAll['Tong Tai san']
DataAll['BLEV']=DataAll['Tong No phai tra']/DataAll['Tong Tai san']

# %%
Output=DataAll.iloc[:,[0,1,2,3,4,13,15,16,17,18,19,20,22,23,24,25,26,27,28]]
DataAll
# Out:
#      Ma CK                   Ten Cong ty    San            Nhom nganh  \
# 0      ACV            Cảng Hàng không VN  UPCOM        Công nghiệp L1
# 1      MSN                Tập đoàn Masan   HOSE     Hàng Tiêu dùng L1
# 2      VNM                      VINAMILK   HOSE     Hàng Tiêu dùng L1
# 3      HPG                      Hòa Phát   HOSE    Nguyên vật liệu L1
# 4      SAB                        SABECO   HOSE     Hàng Tiêu dùng L1
# ...    ...                           ...    ...                   ...
# 5279   GDA                    Tôn Đông Á   HOSE    Nguyên vật liệu L1
# 5280   DHQ          Duyên hải Quảng Ninh  UPCOM  Dịch vụ Tiêu dùng L1
# 5281   DTJ    ĐT XD Viễn thông Đồng Tháp  UPCOM        Công nghiệp L1
# 5282   DTN               Diêm Thống Nhất  UPCOM     Hàng Tiêu dùng L1
# 5283   C36  XD công trình giao thông 236  UPCOM        Công nghiệp L1
#
#      Tong Tai san Tong No phai tra Von Chu so huu No ngan han No dai han  \
# 0        53624854         22838548       30786305     7683984   15154564
# 1        64578613         30498935       34079678    15795515   14703420
# 2        37366108         11094739       26271369    10639592     455147
# 3        78223007         37600057       40622949    22636149   14963908
# 4        22366742          6254837       16111905     5925696     329140
# ...           ...              ...            ...         ...        ...
# 5279     12648113          9196195        3451918     8745065     451129
# 5280          NaN              NaN            NaN         NaN        NaN
# 5281          NaN              NaN            NaN         NaN        NaN
# 5282        41094            12358          28735       12358          0
# 5283          NaN              NaN            NaN         NaN        NaN
#
#      Tai san co dinh  ...     GRWTH       SIZE      EBIT      PROF      LIQD  \
# 0           18447261  ...  0.006047  17.797523   7713260  0.143837  6.978783
# 1           29203764  ...  0.004478  17.983394   8911355  0.137992  4.088415
# 2           13365353  ...   0.00572  17.436275  12103064  0.323905  3.511987
# 3           12782560  ...  0.003428  18.175074  10610934   0.13565  3.455668
# 4            4567091  ...  0.007244  16.923086   5425684  0.242578  3.774534
# ...              ...  ...       ...        ...       ...       ...       ...
# 5279         2834481  ...       0.0  16.353019   1709097  0.135127  1.446314
# 5280             NaN  ...       NaN        NaN       NaN       NaN       NaN
# 5281             NaN  ...       NaN        NaN       NaN       NaN       NaN
# 5282            3887  ...       0.0  10.623617      2552  0.062102  3.325295
# 5283             NaN  ...       NaN        NaN       NaN       NaN       NaN
#
#           UNIQ      TANG     STLEV     LTLEV      BLEV
# 0     0.154697  0.344006  0.143291  0.282603  0.425895
# 1     0.407352   0.45222  0.244594  0.227682  0.472276
# 2     0.748019  0.357687  0.284739  0.012181   0.29692
# 3     0.564612  0.163412   0.28938  0.191298  0.480678
# 4     1.245797  0.204191  0.264933  0.014716  0.279649
# ...        ...       ...       ...       ...       ...
# 5279  1.776551  0.224103  0.691413  0.035668   0.72708
# 5280       NaN       NaN       NaN       NaN       NaN
# 5281       NaN       NaN       NaN       NaN       NaN
# 5282  2.605636  0.094588  0.300725       0.0  0.300725
# 5283       NaN       NaN       NaN       NaN       NaN
#
# [5284 rows x 29 columns]

# %%
#FILTER : Công ty có Total Asset >= 1000B and MarCap >= 1000B 
Output_2021=Output[Output['Nam'] == 2021].sort_values(by='Tong Tai san', ascending=False)
Top_Tickets=Output_2021.loc[(Output['Tong Tai san']>=1000*10**3) & (Output['Von hoa thi truong']>=1000)].reset_index(drop=True)
Top_Tickets=Top_Tickets.iloc[:,[0,1]]
Top_Tickets['ID_TICKET'] = np.arange(Top_Tickets.shape[0])
Top_Tickets=Top_Tickets.iloc[:,[2,0]]

Output=pd.merge(Output, Top_Tickets, on='Ma CK', how='inner')
Output
# Out:
#     Ma CK           Ten Cong ty    San            Nhom nganh Tong Tai san  \
# 0     ACV    Cảng Hàng không VN  UPCOM        Công nghiệp L1     53624854
# 1     ACV    Cảng Hàng không VN  UPCOM        Công nghiệp L1     58176195
# 2     ACV    Cảng Hàng không VN  UPCOM        Công nghiệp L1     56902290
# 3     ACV    Cảng Hàng không VN  UPCOM        Công nghiệp L1     54979483
# 4     MSN        Tập đoàn Masan   HOSE     Hàng Tiêu dùng L1     64578613
# ..    ...                   ...    ...                   ...          ...
# 915   DHT      Dược phẩm Hà Tây    HNX  Dịch vụ Tiêu dùng L1      1237590
# 916   ACL  Thủy sản CL An Giang   HOSE     Hàng Tiêu dùng L1      1343377
# 917   ACL  Thủy sản CL An Giang   HOSE     Hàng Tiêu dùng L1      1461188
# 918   ACL  Thủy sản CL An Giang   HOSE     Hàng Tiêu dùng L1      1659542
# 919   ACL  Thủy sản CL An Giang   HOSE     Hàng Tiêu dùng L1      1458179
#
#     Von hoa thi truong   Nam   GDP  COVID   INDS     GRWTH       SIZE  \
# 0               186158  2018  7.17      0    1.0  0.006047  17.797523
# 1               186158  2019  7.02      0    1.0  0.005065  17.878987
# 2               186158  2020  2.91      1    1.0  0.004956  17.856846
# 3               186158  2021  2.58      1    1.0  0.004944  17.822471
# 4               152624  2018  7.17      0    2.0  0.004478  17.983394
# ..                 ...   ...   ...    ...    ...       ...        ...
# 915               1052  2021  2.58      1    5.0  0.001396  14.028676
# 916               1026  2018  7.17      0    2.0  0.001836  14.110697
# 917               1026  2019  7.02      0    2.0   0.00154  14.194760
# 918               1026  2020  2.91      1    2.0  0.001477  14.322052
# 919               1026  2021  2.58      1    2.0  0.001452  14.192699
#
#          PROF       LIQD      UNIQ      TANG     STLEV     LTLEV      BLEV  \
# 0    0.143837   6.978783  0.154697  0.344006  0.143291  0.282603  0.425895
# 1    0.176227   8.925203  0.154615  0.280963  0.112042  0.256132  0.368174
# 2    0.036844  14.618409  0.112088  0.251948  0.068407  0.271423  0.339829
# 3    0.019627  14.907657  0.100717  0.227536   0.06708  0.248071   0.31515
# 4    0.137992   4.088415  0.407352   0.45222  0.244594  0.227682  0.472276
# ..        ...        ...       ...       ...       ...       ...       ...
# 915  0.083635   2.583275  1.175948  0.120905  0.387106  0.004174  0.391281
# 916  0.224033    1.71215  0.937955  0.265676  0.584061       0.0  0.584061
# 917  0.137615   1.838178  0.754385  0.236049  0.544017       0.0  0.544017
# 918   0.04567   1.719587  0.483084  0.194184  0.581535       0.0  0.581535
# 919  0.054764   1.939775  0.726451  0.195431  0.515524       0.0  0.515524
#
#      ID_TICKET
# 0            8
# 1            8
# 2            8
# 3            8
# 4            1
# ..         ...
# 915        214
# 916        202
# 917        202
# 918        202
# 919        202
#
# [920 rows x 20 columns]

# %%
Output[Output['Nhom nganh'] == "Dược phẩm và Y tế L1"].sort_values(by='Tong Tai san', ascending=False)
# Out:
#     Ma CK                    Ten Cong ty    San            Nhom nganh  \
# 322   DVN     Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 323   DVN     Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 320   DVN     Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 321   DVN     Tổng Công ty Dược Việt Nam  UPCOM  Dược phẩm và Y tế L1
# 143   DHG                 Dược Hậu Giang   HOSE  Dược phẩm và Y tế L1
# 142   DHG                 Dược Hậu Giang   HOSE  Dược phẩm và Y tế L1
# 140   DHG                 Dược Hậu Giang   HOSE  Dược phẩm và Y tế L1
# 141   DHG                 Dược Hậu Giang   HOSE  Dược phẩm và Y tế L1
# 719   PBC       Dược Phẩm TW 1- Pharbaco  UPCOM  Dược phẩm và Y tế L1
# 355   IMP                      IMEXPHARM   HOSE  Dược phẩm và Y tế L1
# 354   IMP                      IMEXPHARM   HOSE  Dược phẩm và Y tế L1
# 718   PBC       Dược Phẩm TW 1- Pharbaco  UPCOM  Dược phẩm và Y tế L1
# 717   PBC       Dược Phẩm TW 1- Pharbaco  UPCOM  Dược phẩm và Y tế L1
# 353   IMP                      IMEXPHARM   HOSE  Dược phẩm và Y tế L1
# 666   DCL             Dược phẩm Cửu Long   HOSE  Dược phẩm và Y tế L1
# 667   DCL             Dược phẩm Cửu Long   HOSE  Dược phẩm và Y tế L1
# 352   IMP                      IMEXPHARM   HOSE  Dược phẩm và Y tế L1
# 664   DCL             Dược phẩm Cửu Long   HOSE  Dược phẩm và Y tế L1
# 665   DCL             Dược phẩm Cửu Long   HOSE  Dược phẩm và Y tế L1
# 395   TRA                       Traphaco   HOSE  Dược phẩm và Y tế L1
# 394   TRA                       Traphaco   HOSE  Dược phẩm và Y tế L1
# 679   DMC              Dược phẩm DOMESCO   HOSE  Dược phẩm và Y tế L1
# 457   DBD       Dược - TB Y tế Bình Định   HOSE  Dược phẩm và Y tế L1
# 392   TRA                       Traphaco   HOSE  Dược phẩm và Y tế L1
# 393   TRA                       Traphaco   HOSE  Dược phẩm và Y tế L1
# 459  14.259887    0.1499    5.43452  0.600147  0.158437  0.184009  0.084644
# 677  14.242771  0.190519   5.483646  0.636415    0.1308   0.18236  0.000793
# 871  14.240803  0.062995   9.733623  0.072115  0.102125  0.102737  0.103667
# 676  14.197426   0.19541   4.380065  0.611633  0.126713  0.228307  0.000722
# 678  14.196671  0.153649   9.915218  0.692282  0.130306  0.100855  0.000656
# 458  14.178353  0.138986   4.132005  0.532774  0.172965  0.242013  0.070203
# 456  14.176215  0.145985   2.884145  0.678289  0.152587  0.346723  0.032326
# 563  14.066984   0.14615   4.961969  0.156897  0.743101  0.201533   0.19172
# 711  14.029169  0.132499   2.528838   0.55213  0.204138  0.395439  0.004477
# 708  13.988954  0.114255     2.1338  0.480422  0.212904  0.468647   0.00502
# 709  13.981051  0.117542    2.42458  0.485188  0.205898  0.412443  0.004807
# 562  13.961423  0.121146   8.476762  0.155491  0.767839   0.11797  0.331079
# 710  13.957552  0.119959   2.636642  0.511885   0.21476   0.37927  0.004297
# 716  13.833971  0.013115   1.843144  1.069762  0.181413  0.542551  0.002172
# 870  13.732631  0.100955  13.883916  0.087689  0.064633  0.072026  0.037987
# 561  13.687624  0.115622   8.941521  0.189809  0.472247  0.111838  0.287523
# 869  13.678521  0.259734  23.623825  0.285203  0.081024   0.04233  0.049857
# 868  13.387317  0.340609  10.131761  0.345644  0.117581    0.0987  0.026431
# 560  13.152015  0.174236  10.456341  0.343003  0.126303  0.095636  0.050654
#
#          BLEV  ID_TICKET
# 322  0.523373         87
# 323  0.489138         87
# 320  0.534266         87
# 321  0.505841         87
# 143  0.178558        106
# 142  0.197743        106
# 140  0.252428        106
# 141  0.185508        106
# 719  0.546916        148
# 355   0.21802        163
# 354  0.174566        163
# 718  0.531615        148
# 717   0.74499        148
# 353  0.156068        163
# 666   0.46068        184
# 667  0.426359        184
# 352  0.151971        163
# 664  0.534858        184
# 665   0.48354        184
# 395  0.257496        186
# 394   0.28978        186
# 679  0.157733        189
# 457  0.424574        195
# 392  0.303579        186
# 393  0.288564        186
# 459  0.268653        195
# 677  0.183153        189
# 871  0.206405        199
# 676   0.22903        189
# 678  0.101511        189
# 458  0.312217        195
# 456   0.37905        195
# 563  0.393253        209
# 711  0.399917        213
# 708  0.473668        213
# 709  0.417249        213
# 562   0.44905        209
# 710  0.383568        213
# 716  0.544724        148
# 870  0.110013        199
# 561  0.399362        209
# 869  0.092187        199
# 868  0.125133        199
# 560  0.146291        209

# %%
Top_Tickets[Output['Nhom nganh'] == "Dược phẩm và Y tế L1"].sort_values(by='Tong Tai san', ascending=False)

# %%
Top_Tickets
# Out:
#      ID_TICKET Ma CK
# 0            0   HPG
# 1            1   MSN
# 2            2   GVR
# 3            3   BSR
# 4            4   PLX
# ..         ...   ...
# 221        221   VGR
# 222        222   DSP
# 223        223   CQN
# 224        224   GVT
# 225        225   PAT
#
# [226 rows x 2 columns]

# %%
# EXPORT FILE DATA
with pd.ExcelWriter('Report.xlsx') as writer:
    DataAll.to_excel(writer, sheet_name='Data')
    Output.to_excel(writer, sheet_name='Output')
    Top_Tickets.to_excel(writer,sheet_name='Top Tickets')
